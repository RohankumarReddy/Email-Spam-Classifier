# %%
import pickle
bnb, cv = pickle.load(open('model_bundle.pkl', 'rb'))

# %%
msg = input("Enter message: ")

clean = transform_text(msg)
vector = cv.transform([clean]).toarray()

result = bnb.predict(vector)

if result[0] == 0:
    print("Not Spam")
else:
    print("Spam")
# Out:
# Spam
